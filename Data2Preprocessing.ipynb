# %% [markdown]
# # Inport Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data exploring and preprocessing

# %%
data2=pd.read_csv('/content/drive/MyDrive/IT Project/Code/dataset/source_data2.csv')

# %%
data2.shape
# Out:
# (16383, 9)

# %%
data2.head()
# Out:
#                            Supplier       Date Type  Invoice number  \
# 0  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
# 1  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
# 2  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
# 3  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
# 4  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
#
#   Product ID            Description  Quantity  Price  Total Amount
# 0   7.70E+12             TINTE IRIS      12.0   1716       20592.0
# 1       5210   CANDELA CON EXTENSOR      25.0   2286       57150.0
# 2   7.45E+12        SUPER GLUE *10G      12.0    575        6900.0
# 3   6.98E+12   CINTA NEGRA AISLANTE      10.0    886        8860.0
# 4   6.95E+12  PEGANTE SMATPEGA *5GR      12.0    263        3156.0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16383 entries, 0 to 16382
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supplier        16383 non-null  object
#  1   Date            16383 non-null  object
#  2   Type            16383 non-null  object
#  3   Invoice number  16383 non-null  int64
#  4   Product ID      16383 non-null  object
#  5   Description     16383 non-null  object
#  6   Quantity        16383 non-null  float64
#  7   Price           16383 non-null  int64
#  8   Total Amount    16383 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
# Drop data Nan
data2.dropna(inplace = True)

# %%
# Check the data Nan and data null
data2.isna().sum(), data2.isnull().sum()
# Out:
# (Supplier          0
#  Date              0
#  Type              0
#  Invoice number    0
#  Product ID        0
#  Description       0
#  Quantity          0
#  Price             0
#  Total Amount      0
#  dtype: int64,
#  Supplier          0
#  Date              0
#  Type              0
#  Invoice number    0
#  Product ID        0
#  Description       0
#  Quantity          0
#  Price             0
#  Total Amount      0
#  dtype: int64)

# %%
data2.head()
# Out:
#                            Supplier       Date Type  Invoice number  \
# 0  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
# 1  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
# 2  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
# 3  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
# 4  CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022   FC           28266
#
#   Product ID            Description  Quantity  Price  Total Amount
# 0   7.70E+12             TINTE IRIS      12.0   1716       20592.0
# 1       5210   CANDELA CON EXTENSOR      25.0   2286       57150.0
# 2   7.45E+12        SUPER GLUE *10G      12.0    575        6900.0
# 3   6.98E+12   CINTA NEGRA AISLANTE      10.0    886        8860.0
# 4   6.95E+12  PEGANTE SMATPEGA *5GR      12.0    263        3156.0

# %%
features_data =  ['Supplier', 'Date','Invoice number', 'Description']
df = data2[features_data]

# %%
df.head(20)
# Out:
#                             Supplier       Date  Invoice number  \
# 0   CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022           28266
# 1   CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022           28266
# 2   CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022           28266
# 3   CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022           28266
# 4   CAMILO ANDRES JARAMILLO GORDILLO  1/14/2022           28266
# 5   CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 6   CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 7   CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 8   CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 9   CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 10  CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 11  CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 12  CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 13  CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 14  CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 15  CAMILO ANDRES JARAMILLO GORDILLO  1/28/2022           29552
# 16  CAMILO ANDRES JARAMILLO GORDILLO  2/10/2022           30854
# 17  CAMILO ANDRES JARAMILLO GORDILLO  2/10/2022           30854
# 18  CAMILO ANDRES JARAMILLO GORDILLO  2/10/2022           30854
# 19  CAMILO ANDRES JARAMILLO GORDILLO  2/10/2022           30854
#
#                        Description
# 0                       TINTE IRIS
# 1             CANDELA CON EXTENSOR
# 2                  SUPER GLUE *10G
# 3             CINTA NEGRA AISLANTE
# 4            PEGANTE SMATPEGA *5GR
# 5                  PEINETA PEQUEÑA
# 6              PEINETA SACA PIOJOS
# 7                      VELA VOLCAN
# 8                  PEINETA MACHETE
# 9   MAQUINA DE AFEITAR DORCO NEGRA
# 10  CINTA TRANSPARENTE ANCHA 25MTS
# 11                 SUPER GLUE *10G
# 12                      TINTE IRIS
# 13           PEGANTE SMATPEGA *5GR
# 14       CINTA DE ENMASCARAR 18X20
# 15           PEINETA COLA DE RATON
# 16      CUCHILLA EN HOJA X 5 DORCO
# 17  MAQUINA DE AFEITAR DORCO NEGRA
# 18                 SUPER GLUE *10G
# 19               GUANTE DE NITRILO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16383 entries, 0 to 16382
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Supplier        16383 non-null  object
#  1   Date            16383 non-null  object
#  2   Invoice number  16383 non-null  int64
#  3   Description     16383 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 512.1+ KB

# %%
# Drop transactions with missing 'Supplier name', 'Date','Invoice number', 'Description'
df.dropna(axis=0, subset=features_data, inplace= True)
# Out:
# <ipython-input-46-5fdcf726afc7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=0, subset=features_data, inplace= True)

# %%
df.shape
# Out:
# (16383, 4)

# %%
# Find number of missing values in each column
df.isna().sum()
# Out:
# Supplier          0
# Date              0
# Invoice number    0
# Description       0
# dtype: int64

# %%
# Summary statistics of categorical variables
df.select_dtypes(include='object').describe().T
# Out:
#              count unique                          top  freq
# Supplier     16383     21  TERCEROS VARIOS Y/O GENERAL  5688
# Date         16383    314                    2/11/2022   233
# Description  16383   3830            MANI JOSSEB *210G   136

# %%
df = df.groupby(['Date','Invoice number'])['Description'].apply(list).reset_index()

# %%
# Chuyển đổi cột 'Date' thành kiểu datetime
df['Date'] = pd.to_datetime(df['Date'])

# Sắp xếp theo cột 'Date' tăng dần
df = df.sort_values(by='Date')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1014 entries, 32 to 270
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1014 non-null   datetime64[ns]
#  1   Invoice number  1014 non-null   int64
#  2   Description     1014 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 31.7+ KB

# %%
# Summary statistics of categorical variables
df.select_dtypes(include='int64').describe().T
# Out:
#                  count          mean           std  min     25%    50%  \
# Invoice number  1014.0  6.582625e+06  1.956002e+08  1.0  245.25  497.5
#
#                     75%           max
# Invoice number  39206.0  6.225022e+09

# %%
# Summary statistics of categorical variables
df.select_dtypes(include='object').describe().T
# Out:
#             count unique             top freq
# Description  1014    975  [AZUCAR BULTO]    6

# %%
# Some transactions have a product, this is unnecessary data. So we will delete them.
# Remove description with length equal to 1
indx = df[df.Description.str.len() < 3].index
df.drop(index=indx, inplace=True)

# %%
df.head()
# Out:
#          Date  Invoice number  \
# 32 2022-01-02            4619
# 66 2022-01-03            4799
# 69 2022-01-04            4423
# 70 2022-01-04           64974
# 71 2022-01-04           82486
#
#                                           Description
# 32  [CEBOLLA LARGA, PAPA PARDA, CEBOLLA  MORADA, M...
# 66  [CONDIMENTO DE TODO AJI, CONDIMENTOS DE TODO A...
# 69  [LULO, MALLA TOMATE CHONTO, PAPA PARDA, MANGO ...
# 70  [MANUELITA LIGHT 850G, AREPA CON QUESO LA CUMB...
# 71  [MANI MOTO FLAMIN HOT, MANI MOTO MEGA QUESO, P...

# %% [markdown]
# # Feature Engineering

# %%
def convert_to_codes(data):
  # Create a unique mapping of categories to codes
  all_categories = set([category for sublist in data for category in sublist])
  category_to_code = {category: f"C{i+1}" for i, category in enumerate(all_categories)}

  # Replace categories with codes
  description_codes = [[category_to_code[category] for category in sublist] for sublist in data]
  return category_to_code, description_codes

# %%
category_code, description_codes = convert_to_codes(df['Description'])

# %%
df = pd.DataFrame({'Date': df['Date'], 'Description':description_codes})

# %%
df.head()
# Out:
#          Date                                        Description
# 32 2022-01-02  [C491, C263, C3276, C1808, C425, C3677, C3323,...
# 66 2022-01-03                               [C2657, C272, C3272]
# 69 2022-01-04  [C3319, C1851, C263, C1808, C2481, C2969, C231...
# 70 2022-01-04                               [C3705, C767, C3051]
# 71 2022-01-04  [C1254, C1842, C985, C1492, C432, C2293, C280,...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 843 entries, 32 to 268
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         843 non-null    datetime64[ns]
#  1   Description  843 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 19.8+ KB

# %%
df.to_csv('/content/drive/MyDrive/IT Project/Code/dataset/dataset2.csv', index=False)

# %%
with open('/content/drive/MyDrive/IT Project/Code/dataset/category_codes_dataset2.csv', 'w', newline='') as csvfile:
    fieldnames = ['Category', 'Code']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for category, code in category_code.items():
      writer.writerow({'Category': category, 'Code': code})
